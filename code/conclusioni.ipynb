# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import fig_size

# %matplotlib widget

width = 469.75502
graph_path = '../assets/'
data_path = '../data/'
table_path = '../tables/'

mpl.rcParams.update({
    # Use LaTeX to write all text
    "text.usetex": True,
    "font.family": "serif",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 11,
    "font.size": 11,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
})

# %%
fig, ax = plt.subplots(figsize=fig_size.from_pt(width))

ax.errorbar(x=0, y=11.8, yerr=0.6, fmt='o', markersize=2, linewidth=0.8, capsize=3, label=r'$f_{\tau}$')
ax.errorbar(x=1, y=12.5, yerr=0.5, fmt='o', markersize=2, linewidth=0.8, capsize=3, label=r'$f_{C}$')
ax.errorbar(x=2, y=12.3, yerr=0.5, fmt='o', markersize=2, linewidth=0.8, capsize=3, label=r'$f_{R}$')
ax.set_xlim(-1, 3)
ax.set_xticks([])

ax.fill_between(ax.get_xlim(), 12.4, 12, alpha=0.2, color='r', label=r'$f_{0}$ compatibile')

ax.set_ylabel(r'$f \; (kHz)$')

ax.minorticks_on()
ax.grid(True, which='major', axis='y', lw=0.8)
ax.grid(True, which='minor', axis='y', lw=0.5)
ax.legend()

fig.savefig(graph_path + 'f_0_compatibili.pdf', format='pdf', bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
