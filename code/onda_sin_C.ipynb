# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import fig_size

# %matplotlib widget

width = 469.75502
graph_path = '../assets/'
data_path = '../data/'
table_path = '../tables/'

mpl.rcParams.update({
    # Use LaTeX to write all text
    "text.usetex": True,
    "font.family": "serif",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 11,
    "font.size": 11,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 9,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
})

# %%
df: pd.DataFrame = pd.read_csv(data_path + 'V_C.csv', sep=r'\s*,\s*', engine='python')
df = df.sort_values('f')
df
# Out:
#     V_in  V_in/sc  V_out  V_out/sc         f   f/sc         T       t  t/sc
# 0   6.96        1  6.920      1.00    0.5155    0.5  1940.000  13.700  2.50
# 1   7.04        1  6.920      1.00    1.0240    5.0   976.000  13.500  2.50
# 2   7.04        1  6.860      1.00    2.4950    5.0   400.700  13.200  2.50
# 5   7.04        1  6.750      1.00    3.5250    5.0   283.600  12.800  5.00
# 3   7.04        1  6.640      1.00    4.0100    5.0   249.200  12.700  2.50
# 4   7.04        1  6.000      1.00    7.0420   50.0   141.900  11.900  2.50
# 6   6.00        1  3.340      1.00   15.5500   50.0    64.300   9.200  2.50
# 7   5.72        1  2.440      0.50   25.4600   50.0    39.280   6.760  1.00
# 8   5.60        1  1.760      0.50   36.3700   50.0    27.480   5.300  2.50
# 9   5.44        1  0.628      0.10  104.7000  500.0     9.540   2.220  0.50
# 10  5.44        1  0.424      0.10  156.0000  500.0     6.410   1.520  1.00
# 11  5.36        1  0.258      0.05  254.1000  500.0     3.934   0.950  0.50
# 12  5.28        1  0.181      0.02  356.6000  500.0     2.804   0.650  0.25
# 13  5.24        1  0.172      0.05  376.5000  500.0     2.660   0.636  0.10
# 14  5.02        1  0.138      0.02  459.1000  500.0     2.178   0.520  0.25

# %% [markdown]
# ### Errori su $V_{in}$ e $V_{out}$

# %%
df['dV_in'] = df['V_in/sc'] / 10
df['dV_out'] = df['V_out/sc'] / 10
df
# Out:
#     V_in  V_in/sc  V_out  V_out/sc         f   f/sc         T       t  t/sc  \
# 0   6.96        1  6.920      1.00    0.5155    0.5  1940.000  13.700  2.50
# 1   7.04        1  6.920      1.00    1.0240    5.0   976.000  13.500  2.50
# 2   7.04        1  6.860      1.00    2.4950    5.0   400.700  13.200  2.50
# 5   7.04        1  6.750      1.00    3.5250    5.0   283.600  12.800  5.00
# 3   7.04        1  6.640      1.00    4.0100    5.0   249.200  12.700  2.50
# 4   7.04        1  6.000      1.00    7.0420   50.0   141.900  11.900  2.50
# 6   6.00        1  3.340      1.00   15.5500   50.0    64.300   9.200  2.50
# 7   5.72        1  2.440      0.50   25.4600   50.0    39.280   6.760  1.00
# 8   5.60        1  1.760      0.50   36.3700   50.0    27.480   5.300  2.50
# 9   5.44        1  0.628      0.10  104.7000  500.0     9.540   2.220  0.50
# 10  5.44        1  0.424      0.10  156.0000  500.0     6.410   1.520  1.00
# 11  5.36        1  0.258      0.05  254.1000  500.0     3.934   0.950  0.50
# 12  5.28        1  0.181      0.02  356.6000  500.0     2.804   0.650  0.25
# 13  5.24        1  0.172      0.05  376.5000  500.0     2.660   0.636  0.10
# 14  5.02        1  0.138      0.02  459.1000  500.0     2.178   0.520  0.25
#
#     dV_in  dV_out
# 0     0.1   0.100
# 1     0.1   0.100
# 2     0.1   0.100
# 5     0.1   0.100
# 3     0.1   0.100
# 4     0.1   0.100
# 6     0.1   0.100
# 7     0.1   0.050
# 8     0.1   0.050
# 9     0.1   0.010
# 10    0.1   0.010
# 11    0.1   0.005
# 12    0.1   0.002
# 13    0.1   0.005
# 14    0.1   0.002

# %% [markdown]
# ### Errori su $t$

# %%
df['dt'] = df['t/sc'] / 10
df
# Out:
#     V_in  V_in/sc  V_out  V_out/sc         f   f/sc         T       t  t/sc  \
# 0   6.96        1  6.920      1.00    0.5155    0.5  1940.000  13.700  2.50
# 1   7.04        1  6.920      1.00    1.0240    5.0   976.000  13.500  2.50
# 2   7.04        1  6.860      1.00    2.4950    5.0   400.700  13.200  2.50
# 5   7.04        1  6.750      1.00    3.5250    5.0   283.600  12.800  5.00
# 3   7.04        1  6.640      1.00    4.0100    5.0   249.200  12.700  2.50
# 4   7.04        1  6.000      1.00    7.0420   50.0   141.900  11.900  2.50
# 6   6.00        1  3.340      1.00   15.5500   50.0    64.300   9.200  2.50
# 7   5.72        1  2.440      0.50   25.4600   50.0    39.280   6.760  1.00
# 8   5.60        1  1.760      0.50   36.3700   50.0    27.480   5.300  2.50
# 9   5.44        1  0.628      0.10  104.7000  500.0     9.540   2.220  0.50
# 10  5.44        1  0.424      0.10  156.0000  500.0     6.410   1.520  1.00
# 11  5.36        1  0.258      0.05  254.1000  500.0     3.934   0.950  0.50
# 12  5.28        1  0.181      0.02  356.6000  500.0     2.804   0.650  0.25
# 13  5.24        1  0.172      0.05  376.5000  500.0     2.660   0.636  0.10
# 14  5.02        1  0.138      0.02  459.1000  500.0     2.178   0.520  0.25
#
#     dV_in  dV_out     dt
# 0     0.1   0.100  0.250
# 1     0.1   0.100  0.250
# 2     0.1   0.100  0.250
# 5     0.1   0.100  0.500
# 3     0.1   0.100  0.250
# 4     0.1   0.100  0.250
# 6     0.1   0.100  0.250
# 7     0.1   0.050  0.100
# 8     0.1   0.050  0.250
# 9     0.1   0.010  0.050
# 10    0.1   0.010  0.100
# 11    0.1   0.005  0.050
# 12    0.1   0.002  0.025
# 13    0.1   0.005  0.010
# 14    0.1   0.002  0.025

# %% [markdown]
# ### Calcolo del modulo della funzione di trasferimento

# %%
df['|A|'] = df['V_out'] / df['V_in']
eV_in = df['dV_in'] / df['V_in']
eV_out = df['dV_out'] / df['V_out']
df['d|A|'] = df['|A|'] * (eV_in + eV_out)
df
# Out:
#     V_in  V_in/sc  V_out  V_out/sc         f   f/sc         T       t  t/sc  \
# 0   6.96        1  6.920      1.00    0.5155    0.5  1940.000  13.700  2.50
# 1   7.04        1  6.920      1.00    1.0240    5.0   976.000  13.500  2.50
# 2   7.04        1  6.860      1.00    2.4950    5.0   400.700  13.200  2.50
# 5   7.04        1  6.750      1.00    3.5250    5.0   283.600  12.800  5.00
# 3   7.04        1  6.640      1.00    4.0100    5.0   249.200  12.700  2.50
# 4   7.04        1  6.000      1.00    7.0420   50.0   141.900  11.900  2.50
# 6   6.00        1  3.340      1.00   15.5500   50.0    64.300   9.200  2.50
# 7   5.72        1  2.440      0.50   25.4600   50.0    39.280   6.760  1.00
# 8   5.60        1  1.760      0.50   36.3700   50.0    27.480   5.300  2.50
# 9   5.44        1  0.628      0.10  104.7000  500.0     9.540   2.220  0.50
# 10  5.44        1  0.424      0.10  156.0000  500.0     6.410   1.520  1.00
# 11  5.36        1  0.258      0.05  254.1000  500.0     3.934   0.950  0.50
# 12  5.28        1  0.181      0.02  356.6000  500.0     2.804   0.650  0.25
# 13  5.24        1  0.172      0.05  376.5000  500.0     2.660   0.636  0.10
# 14  5.02        1  0.138      0.02  459.1000  500.0     2.178   0.520  0.25
#
#     dV_in  dV_out     dt       |A|      d|A|
# 0     0.1   0.100  0.250  0.994253  0.028653
# 1     0.1   0.100  0.250  0.982955  0.028167
# 2     0.1   0.100  0.250  0.974432  0.028046
# 5     0.1   0.100  0.500  0.958807  0.027824
# 3     0.1   0.100  0.250  0.943182  0.027602
# 4     0.1   0.100  0.250  0.852273  0.026311
# 6     0.1   0.100  0.250  0.556667  0.025944
# 7     0.1   0.050  0.100  0.426573  0.016199
# 8     0.1   0.050  0.250  0.314286  0.014541
# 9     0.1   0.010  0.050  0.115441  0.003960
# 10    0.1   0.010  0.100  0.077941  0.003271
# 11    0.1   0.005  0.050  0.048134  0.001831
# 12    0.1   0.002  0.025  0.034280  0.001028
# 13    0.1   0.005  0.010  0.032824  0.001581
# 14    0.1   0.002  0.025  0.027490  0.000946

# %%
columns = ['V_in', 'dV_in', 'V_out', 'dV_out', 'f', 't', 'dt']

if False:
    df.to_latex(
        buf = table_path + 'onda_sin_VC.tex',
        columns = columns,
        header = [r'$V_{in} \; (V)$', r'$\delta V_{in} \; (V)$', r'$V_{out} \; (V)$', r'$\delta V_{out} \; (V)$', r'$f \; (kHz)$', r'$t \; (\mu s)$', r'$\delta t \; (\mu s)$'],
        index = False,
        bold_rows = True,
        column_format = 'cc|cc|ccc',
        escape = False,
    )
d = df.loc[:, columns]
d
# Out:
#     V_in  dV_in  V_out  dV_out         f       t     dt
# 0   6.96    0.1  6.920   0.100    0.5155  13.700  0.250
# 1   7.04    0.1  6.920   0.100    1.0240  13.500  0.250
# 2   7.04    0.1  6.860   0.100    2.4950  13.200  0.250
# 5   7.04    0.1  6.750   0.100    3.5250  12.800  0.500
# 3   7.04    0.1  6.640   0.100    4.0100  12.700  0.250
# 4   7.04    0.1  6.000   0.100    7.0420  11.900  0.250
# 6   6.00    0.1  3.340   0.100   15.5500   9.200  0.250
# 7   5.72    0.1  2.440   0.050   25.4600   6.760  0.100
# 8   5.60    0.1  1.760   0.050   36.3700   5.300  0.250
# 9   5.44    0.1  0.628   0.010  104.7000   2.220  0.050
# 10  5.44    0.1  0.424   0.010  156.0000   1.520  0.100
# 11  5.36    0.1  0.258   0.005  254.1000   0.950  0.050
# 12  5.28    0.1  0.181   0.002  356.6000   0.650  0.025
# 13  5.24    0.1  0.172   0.005  376.5000   0.636  0.010
# 14  5.02    0.1  0.138   0.002  459.1000   0.520  0.025

# %%
columns = ['|A|', 'd|A|', 'f']

if False:
    df.to_latex(
        buf = table_path + 'onda_sin_AC.tex',
        columns = columns,
        header = [r'$|A_{C}|$', r'$d|A_{C}|$', r'$f \; (kHz)$'],
        index = False,
        bold_rows = True,
        column_format = 'cc|c',
        escape = False,
    )
d = df.loc[:, columns]
d
# Out:
#          |A|      d|A|         f
# 0   0.994253  0.028653    0.5155
# 1   0.982955  0.028167    1.0240
# 2   0.974432  0.028046    2.4950
# 5   0.958807  0.027824    3.5250
# 3   0.943182  0.027602    4.0100
# 4   0.852273  0.026311    7.0420
# 6   0.556667  0.025944   15.5500
# 7   0.426573  0.016199   25.4600
# 8   0.314286  0.014541   36.3700
# 9   0.115441  0.003960  104.7000
# 10  0.077941  0.003271  156.0000
# 11  0.048134  0.001831  254.1000
# 12  0.034280  0.001028  356.6000
# 13  0.032824  0.001581  376.5000
# 14  0.027490  0.000946  459.1000

# %%
fig, ax = plt.subplots(figsize = fig_size.from_pt(width))
# fig.tight_layout()

ax.set_xscale('log')
ax.set_yscale('log')

ax.errorbar(
    x = df['f'],
    y = df['|A|'], yerr=df['d|A|'],
    fmt='o', markersize = 3,
    capsize = 3, label='Misure con errori'
)

xlim = np.array(ax.get_xlim())

# |A| = 1/sqrt(2)
# A_taglio = lambda x: x - x +(1/2)**(1/2)
# ax.plot(xlim, A_taglio(xlim), linestyle='dashed', lw=0.8, label=r'$1/\sqrt{2}$')

ax.set_xlim(xlim)

ax.minorticks_on()
ax.grid(True, which='major', lw = 1)
ax.grid(True, which='minor', lw = 0.5)

ax.legend()

ax.set_xlabel(r'$f \; (kHz)$')
ax.set_ylabel(r'$|A_{C}|$')

fig.savefig(graph_path + 'onda_sin_AC(f).pdf', format='pdf', bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots(figsize = fig_size.from_pt(width))
# fig.tight_layout()

ax.set_xscale('log')
ax.set_yscale('log')

ax.errorbar(
    x = df['f'],
    y = df['|A|'], yerr=df['d|A|'],
    fmt='o', markersize = 3,
    capsize = 3, label='Misure con errori'
)

xlim = np.array(ax.get_xlim())
ylim = np.array(ax.get_ylim())

# |A| = 1/sqrt(2)
# A_taglio = lambda x: x - x +(1/2)**(1/2)
# ax.plot(xlim, A_taglio(xlim), linestyle='dashed', lw=0.8, label=r'$1/\sqrt{2}$')

# |A| = 1
A_max = lambda x: x - x + 1
ax.plot(xlim, A_max(xlim), lw=0.8, label=r'$|A_{C}| = 1$')

# Minima intercetta
l_min = lambda x: 12/x
ax.plot(xlim, l_min(xlim), lw=0.8, label='Minima intercetta')

# Massima intercetta
l_max = lambda x: 12.5/x
ax.plot(xlim, l_max(xlim), lw=0.8, label='Massima intercetta')

# Minima frequenza di taglio
f_min = lambda y: y - y + 12
ax.plot(f_min(ylim), ylim, lw=0.8, c='purple', label=r'Limiti $f_{C}$')

# Massima frequenza di taglio
f_max = lambda y: y - y + 12.5
ax.plot(f_max(ylim), ylim, lw=0.8, c='purple')

ax.set_xlim(xlim)
ax.set_ylim(ylim)

ax.minorticks_on()
ax.grid(True, which='major', lw = 1)
ax.grid(True, which='minor', lw = 0.5)

ax.legend()

ax.set_xlabel(r'$f \; (kHz)$')
ax.set_ylabel(r'$|A_{C}|$')

fig.savefig(graph_path + 'onda_sin_AC(f)_taglio.pdf', format='pdf', bbox_inches='tight')

# fig.set_size_inches(fig_size.from_pt(width * 0.4))
# ax.get_legend().remove()

ax.set_xlim(11, 14)
ax.set_ylim(0.8, 1.2)

fig.savefig(graph_path + 'onda_sin_AC(f)_taglio_frequenza.pdf', format='pdf', bbox_inches='tight')

# ax.set_xlim(150, 500)
# ax.set_ylim(0.02, 0.1)

# fig.savefig(graph_path + 'onda_sin_AC(f)_taglio_intercette.pdf', format='pdf', bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# fig = plt.figure(figsize=fig_size.from_pt(width, subplots=(3, 2)))
# fig.tight_layout()

# from matplotlib.gridspec import GridSpec

# gs = GridSpec(3, 2, figure=fig)

# ax_main = fig.add_subplot(gs[0:2, 0:2])
# ax_cut = fig.add_subplot(gs[2, 0])
# ax_line = fig.add_subplot(gs[2, 1])

# for ax in (ax_main, ax_cut, ax_line):
#     ax.set_xscale('log')
#     ax.set_yscale('log')

#     ax.errorbar(
#         x = df['f'],
#         y = df['|A|'], yerr=df['d|A|'],
#         fmt='o', markersize = 3,
#         capsize = 3, label='Misure con errori'
#     )

#     xlim = np.array(ax.get_xlim())
#     ylim = np.array(ax.get_ylim())

#     A_taglio = lambda x: x - x +(1/2)**(1/2)
#     ax.plot(xlim, A_taglio(xlim), linestyle='dashed', lw=0.8, label=r'$1/\sqrt{2}$')

#     A_max = lambda x: x - x + 1
#     ax.plot(xlim, A_max(xlim), lw=0.8, label=r'$1$')

#     l_min = lambda x: 12/x
#     ax.plot(xlim, l_min(xlim), lw=0.8, label='Minima intercetta')

#     l_max = lambda x: 12.5/x
#     ax.plot(xlim, l_max(xlim), lw=0.8, label='Minima intercetta')

#     ax.set_xlim(xlim)
#     ax.set_ylim(ylim)

#     ax.minorticks_on()
#     ax.grid(True, which='major', lw = 1)
#     ax.grid(True, which='minor', lw = 0.5)

#     # ax.set_xlabel(r'$f \; (kHz)$')
#     # ax.set_ylabel(r'$|A_{C}|$')

# ax_main.legend()

# ax_cut.set_xlim(6, 30)
# ax_cut.set_ylim(0.4, 1.1)

# ax_line.set_xlim(150, 500)
# ax_line.set_ylim(0.02, 0.1)

# fig.savefig(graph_path + 'onda_sin_AC(f)_taglio.pdf', format='pdf', bbox_inches='tight')

# %%
df['phi'] = - 2 * np.pi * df['t'] / df['T']
et = df['dt'] / df['t']
df['dphi'] = df['phi'] * et
df
# Out:
#     V_in  V_in/sc  V_out  V_out/sc         f   f/sc         T       t  t/sc  \
# 0   6.96        1  6.920      1.00    0.5155    0.5  1940.000  13.700  2.50
# 1   7.04        1  6.920      1.00    1.0240    5.0   976.000  13.500  2.50
# 2   7.04        1  6.860      1.00    2.4950    5.0   400.700  13.200  2.50
# 5   7.04        1  6.750      1.00    3.5250    5.0   283.600  12.800  5.00
# 3   7.04        1  6.640      1.00    4.0100    5.0   249.200  12.700  2.50
# 4   7.04        1  6.000      1.00    7.0420   50.0   141.900  11.900  2.50
# 6   6.00        1  3.340      1.00   15.5500   50.0    64.300   9.200  2.50
# 7   5.72        1  2.440      0.50   25.4600   50.0    39.280   6.760  1.00
# 8   5.60        1  1.760      0.50   36.3700   50.0    27.480   5.300  2.50
# 9   5.44        1  0.628      0.10  104.7000  500.0     9.540   2.220  0.50
# 10  5.44        1  0.424      0.10  156.0000  500.0     6.410   1.520  1.00
# 11  5.36        1  0.258      0.05  254.1000  500.0     3.934   0.950  0.50
# 12  5.28        1  0.181      0.02  356.6000  500.0     2.804   0.650  0.25
# 13  5.24        1  0.172      0.05  376.5000  500.0     2.660   0.636  0.10
# 14  5.02        1  0.138      0.02  459.1000  500.0     2.178   0.520  0.25
#
#     dV_in  dV_out     dt       |A|      d|A|       phi      dphi
# 0     0.1   0.100  0.250  0.994253  0.028653 -0.044371 -0.000810
# 1     0.1   0.100  0.250  0.982955  0.028167 -0.086909 -0.001609
# 2     0.1   0.100  0.250  0.974432  0.028046 -0.206983 -0.003920
# 5     0.1   0.100  0.500  0.958807  0.027824 -0.283585 -0.011078
# 3     0.1   0.100  0.250  0.943182  0.027602 -0.320210 -0.006303
# 4     0.1   0.100  0.250  0.852273  0.026311 -0.526920 -0.011070
# 6     0.1   0.100  0.250  0.556667  0.025944 -0.898994 -0.024429
# 7     0.1   0.050  0.100  0.426573  0.016199 -1.081322 -0.015996
# 8     0.1   0.050  0.250  0.314286  0.014541 -1.211822 -0.057161
# 9     0.1   0.010  0.050  0.115441  0.003960 -1.462125 -0.032931
# 10    0.1   0.010  0.100  0.077941  0.003271 -1.489928 -0.098022
# 11    0.1   0.005  0.050  0.048134  0.001831 -1.517292 -0.079857
# 12    0.1   0.002  0.025  0.034280  0.001028 -1.456516 -0.056020
# 13    0.1   0.005  0.010  0.032824  0.001581 -1.502295 -0.023621
# 14    0.1   0.002  0.025  0.027490  0.000946 -1.500118 -0.072121

# %%
fig, ax = plt.subplots(figsize = fig_size.from_pt(width))
# fig.tight_layout()

ax.set_xscale('log')

ax.errorbar(
    x = df['f'],
    y = df['phi'], yerr=df['dphi'],
    fmt='o', markersize = 3,
    capsize = 3, label='Misure con errori'
)

xlim = np.array(ax.get_xlim())
ylim = np.array(ax.get_ylim())

phi_taglio = lambda x: x - x - np.pi/4
ax.plot(xlim, phi_taglio(xlim), lw=0.8, label=r'$- \pi/4$')

ax.set_xlim(xlim)
ax.set_ylim(ylim)

ax.minorticks_on()
ax.grid(True, which='major', lw = 1)
ax.grid(True, which='minor', lw = 0.5)

ax.legend()

ax.set_xlabel(r'$f \; (kHz)$')
ax.set_ylabel(r'$|\varphi_{C}| \; (rad)$')

fig.savefig(graph_path + 'onda_sin_phi(f)_C.pdf', format='pdf', bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots(figsize = fig_size.from_pt(width))
# fig.tight_layout()

ax.set_xscale('log')

ax.errorbar(
    x = df['f'],
    y = df['phi'], yerr=df['dphi'],
    fmt='o', markersize = 3,
    capsize = 3, label='Misure con errori'
)

xlim = np.array(ax.get_xlim())
ylim = np.array(ax.get_ylim())

A_taglio = lambda x: x - x - np.pi/4
ax.plot(xlim, A_taglio(xlim), lw=0.8, label=r'$- \pi/4$')

# Minima intercetta
l_min = lambda x: -np.log10(x/11.9)*1.08 - np.pi/4
ax.plot(xlim, l_min(xlim), lw=0.8, label='Minima intercetta')

# Massima intercetta
l_max = lambda x: -np.log10(x/12.5)*1.08 - np.pi/4
ax.plot(xlim, l_max(xlim), lw=0.8, label='Massima intercetta')

# Minima frequenza di taglio
f_min = lambda y: y - y + 12
ax.plot(f_min(ylim), ylim, lw=0.8, c='purple', label=r'Limiti $f_{C}$')

# Massima frequenza di taglio
f_max = lambda y: y - y + 12.5
ax.plot(f_max(ylim), ylim, lw=0.8, c='purple')

ax.set_xlim(xlim)
ax.set_ylim(ylim)

ax.minorticks_on()
ax.grid(True, which='major', lw = 1)
ax.grid(True, which='minor', lw = 0.5)

ax.legend()

ax.set_xlabel(r'$f \; (kHz)$')
ax.set_ylabel(r'$|\varphi_{C}| \; (rad)$')

fig.savefig(graph_path + 'onda_sin_phi(f)_C_pendenze.pdf', format='pdf', bbox_inches='tight')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots(figsize = fig_size.from_pt(width))
# fig.tight_layout()

ax.set_xscale('log')

ax.errorbar(
    x = df['f'],
    y = df['phi'], yerr=df['dphi'],
    fmt='o', markersize = 3,
    capsize = 3, label='Misure con errori'
)

xlim = np.array(ax.get_xlim())
ylim = np.array(ax.get_ylim())

A_taglio = lambda x: x - x - np.pi/4
ax.plot(xlim, A_taglio(xlim), lw=0.8, label=r'$- \pi/4$')

# Minima pendenza
l_min = lambda x: -np.log10(x/12.6)*0.98 - np.pi/4
ax.plot(xlim, l_min(xlim), lw=0.8, label='Minima pendenza')

# Massima pendenza
l_max = lambda x: -np.log10(x/11.9)*1.18 - np.pi/4
ax.plot(xlim, l_max(xlim), lw=0.8, label='Massima pendenza')

# Minima frequenza di taglio
f_min = lambda y: y - y + 12
ax.plot(f_min(ylim), ylim, lw=0.8, c='purple', label=r'Limiti $f_{C}$')

# Massima frequenza di taglio
f_max = lambda y: y - y + 12.5
ax.plot(f_max(ylim), ylim, lw=0.8, c='purple')

ax.set_xlim(xlim)
ax.set_ylim(ylim)

ax.minorticks_on()
ax.grid(True, which='major', lw = 1)
ax.grid(True, which='minor', lw = 0.5)

ax.legend()

ax.set_xlabel(r'$f \; (kHz)$')
ax.set_ylabel(r'$|\varphi_{C}| \; (rad)$')

ax.set_xlim(6.5, 18)
ax.set_ylim(-1, -0.4)
# Out:
# (-1.0, -0.4)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
